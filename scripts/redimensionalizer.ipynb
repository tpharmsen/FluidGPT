# %%
import os
import h5py
import torch
from pathlib import Path

# Parameters
data_path = '../../data/PoolBoiling-SubCooled-FC72-2D-0.1/'
input_path = os.path.join(data_path, 'downsampled_8/')
output_path = os.path.join(data_path, 'redim_DS8/')
os.makedirs(output_path, exist_ok=True)  # Ensure output directory exists

keys_to_copy = [
    'real-runtime-params',
    'int-runtime-params'
]

TEMPERATURE = 'temperature'

print(f"Scaling temperature data in '{input_path}'\n and saving to '{output_path}'...")
# Process each file in the directory
files = [f for f in os.listdir(input_path) if f.endswith('.hdf5')]

for file in files:
    input_file = os.path.join(input_path, file)
    output_file = os.path.join(output_path, file)

    with h5py.File(input_file, 'r') as input_data:
        # Prepare output HDF5 file
        with h5py.File(output_file, 'w') as output_data:
            filestem = Path(file).stem
            wall_temp = None
            TWALL = 'Twall-'

            for key in input_data.keys():
                dataset = input_data[key][:]
                print(f"Processing key '{key}' in file '{file}' with shape {dataset.shape}")

                # Apply scaling only to the temperature dataset if filename contains 'Twall-'
                if key == TEMPERATURE and TWALL in filestem:
                    scaling_factor = int(filestem[len(TWALL):])  # Extract scaling factor from filename
                    temperature_data = torch.from_numpy(dataset)  # Convert to tensor
                    scaled_temperature = temperature_data * scaling_factor  # Apply scaling
                    scaled_temperature = scaled_temperature.numpy()  # Convert back to NumPy array
                    output_data.create_dataset(TEMPERATURE, data=scaled_temperature)  # Save scaled data
                    wall_temp = scaled_temperature.max()
                    print(f"Wall temperature scaling applied with factor {scaling_factor}. Max wall temp: {wall_temp}")

                else:
                    # Copy other datasets as-is
                    output_data.create_dataset(key, data=dataset)

            print(f"File '{file}' processed and saved to '{output_file}'.")

print("Scaling completed for all files.")
# Out:
# Scaling temperature data in '../../data/PoolBoiling-SubCooled-FC72-2D-0.1/downsampled_8/'
#  and saving to '../../data/PoolBoiling-SubCooled-FC72-2D-0.1/redim_DS8/'...
# Processing key 'dfun' in file 'Twall-79.hdf5' with shape (2001, 48, 48)
# Processing key 'pressure' in file 'Twall-79.hdf5' with shape (2001, 48, 48)
# Processing key 'temperature' in file 'Twall-79.hdf5' with shape (2001, 48, 48)
# Wall temperature scaling applied with factor 79. Max wall temp: 72.1451353653183
# Processing key 'velx' in file 'Twall-79.hdf5' with shape (2001, 48, 48)
# Processing key 'vely' in file 'Twall-79.hdf5' with shape (2001, 48, 48)
# Processing key 'x' in file 'Twall-79.hdf5' with shape (2001, 48, 48)
# Processing key 'y' in file 'Twall-79.hdf5' with shape (2001, 48, 48)
# File 'Twall-79.hdf5' processed and saved to '../../data/PoolBoiling-SubCooled-FC72-2D-0.1/redim_DS8/Twall-79.hdf5'.
# Processing key 'dfun' in file 'Twall-97.hdf5' with shape (2001, 48, 48)
# Processing key 'pressure' in file 'Twall-97.hdf5' with shape (2001, 48, 48)
# Processing key 'temperature' in file 'Twall-97.hdf5' with shape (2001, 48, 48)
# Wall temperature scaling applied with factor 97. Max wall temp: 88.86203861999043
# Processing key 'velx' in file 'Twall-97.hdf5' with shape (2001, 48, 48)
# Processing key 'vely' in file 'Twall-97.hdf5' with shape (2001, 48, 48)
# Processing key 'x' in file 'Twall-97.hdf5' with shape (2001, 48, 48)
# Processing key 'y' in file 'Twall-97.hdf5' with shape (2001, 48, 48)
# File 'Twall-97.hdf5' processed and saved to '../../data/PoolBoiling-SubCooled-FC72-2D-0.1/redim_DS8/Twall-97.hdf5'.
# Processing key 'dfun' in file 'Twall-108.hdf5' with shape (2001, 48, 48)
# Processing key 'pressure' in file 'Twall-108.hdf5' with shape (2001, 48, 48)
# Processing key 'temperature' in file 'Twall-108.hdf5' with shape (2001, 48, 48)
# Wall temperature scaling applied with factor 108. Max wall temp: 100.3248891560948
# Processing key 'velx' in file 'Twall-108.hdf5' with shape (2001, 48, 48)
# Processing key 'vely' in file 'Twall-108.hdf5' with shape (2001, 48, 48)
# Processing key 'x' in file 'Twall-108.hdf5' with shape (2001, 48, 48)
# Processing key 'y' in file 'Twall-108.hdf5' with shape (2001, 48, 48)
# File 'Twall-108.hdf5' processed and saved to '../../data/PoolBoiling-SubCooled-FC72-2D-0.1/redim_DS8/Twall-108.hdf5'.
# Processing key 'dfun' in file 'Twall-100.hdf5' with shape (2001, 48, 48)
# Processing key 'pressure' in file 'Twall-100.hdf5' with shape (2001, 48, 48)
# Processing key 'temperature' in file 'Twall-100.hdf5' with shape (2001, 48, 48)
# Wall temperature scaling applied with factor 100. Max wall temp: 92.02448616130486
# Processing key 'velx' in file 'Twall-100.hdf5' with shape (2001, 48, 48)
# Processing key 'vely' in file 'Twall-100.hdf5' with shape (2001, 48, 48)
# Processing key 'x' in file 'Twall-100.hdf5' with shape (2001, 48, 48)
# Processing key 'y' in file 'Twall-100.hdf5' with shape (2001, 48, 48)
# File 'Twall-100.hdf5' processed and saved to '../../data/PoolBoiling-SubCooled-FC72-2D-0.1/redim_DS8/Twall-100.hdf5'.
# Processing key 'dfun' in file 'Twall-110.hdf5' with shape (2001, 48, 48)
# Processing key 'pressure' in file 'Twall-110.hdf5' with shape (2001, 48, 48)
# Processing key 'temperature' in file 'Twall-110.hdf5' with shape (2001, 48, 48)
# Wall temperature scaling applied with factor 110. Max wall temp: 100.39507228753776
# Processing key 'velx' in file 'Twall-110.hdf5' with shape (2001, 48, 48)
# Processing key 'vely' in file 'Twall-110.hdf5' with shape (2001, 48, 48)
# Processing key 'x' in file 'Twall-110.hdf5' with shape (2001, 48, 48)
# Processing key 'y' in file 'Twall-110.hdf5' with shape (2001, 48, 48)
# File 'Twall-110.hdf5' processed and saved to '../../data/PoolBoiling-SubCooled-FC72-2D-0.1/redim_DS8/Twall-110.hdf5'.
# Processing key 'dfun' in file 'Twall-81.hdf5' with shape (2001, 48, 48)
# Processing key 'pressure' in file 'Twall-81.hdf5' with shape (2001, 48, 48)
# Processing key 'temperature' in file 'Twall-81.hdf5' with shape (2001, 48, 48)
# Wall temperature scaling applied with factor 81. Max wall temp: 73.95051719074843
# Processing key 'velx' in file 'Twall-81.hdf5' with shape (2001, 48, 48)
# Processing key 'vely' in file 'Twall-81.hdf5' with shape (2001, 48, 48)
# Processing key 'x' in file 'Twall-81.hdf5' with shape (2001, 48, 48)
# Processing key 'y' in file 'Twall-81.hdf5' with shape (2001, 48, 48)
# File 'Twall-81.hdf5' processed and saved to '../../data/PoolBoiling-SubCooled-FC72-2D-0.1/redim_DS8/Twall-81.hdf5'.
# Processing key 'dfun' in file 'Twall-90.hdf5' with shape (2001, 48, 48)
# Processing key 'pressure' in file 'Twall-90.hdf5' with shape (2001, 48, 48)
# Processing key 'temperature' in file 'Twall-90.hdf5' with shape (2001, 48, 48)
# Wall temperature scaling applied with factor 90. Max wall temp: 83.17848844337664
# Processing key 'velx' in file 'Twall-90.hdf5' with shape (2001, 48, 48)
# Processing key 'vely' in file 'Twall-90.hdf5' with shape (2001, 48, 48)
# Processing key 'x' in file 'Twall-90.hdf5' with shape (2001, 48, 48)
# Processing key 'y' in file 'Twall-90.hdf5' with shape (2001, 48, 48)
# File 'Twall-90.hdf5' processed and saved to '../../data/PoolBoiling-SubCooled-FC72-2D-0.1/redim_DS8/Twall-90.hdf5'.
# Processing key 'dfun' in file 'Twall-88.hdf5' with shape (2001, 48, 48)
# Processing key 'pressure' in file 'Twall-88.hdf5' with shape (2001, 48, 48)
# Processing key 'temperature' in file 'Twall-88.hdf5' with shape (2001, 48, 48)
# Wall temperature scaling applied with factor 88. Max wall temp: 79.55499376252459
# Processing key 'velx' in file 'Twall-88.hdf5' with shape (2001, 48, 48)
# Processing key 'vely' in file 'Twall-88.hdf5' with shape (2001, 48, 48)
# Processing key 'x' in file 'Twall-88.hdf5' with shape (2001, 48, 48)
# Processing key 'y' in file 'Twall-88.hdf5' with shape (2001, 48, 48)
# File 'Twall-88.hdf5' processed and saved to '../../data/PoolBoiling-SubCooled-FC72-2D-0.1/redim_DS8/Twall-88.hdf5'.
# Processing key 'dfun' in file 'Twall-106.hdf5' with shape (2001, 48, 48)
# Processing key 'pressure' in file 'Twall-106.hdf5' with shape (2001, 48, 48)
# Processing key 'temperature' in file 'Twall-106.hdf5' with shape (2001, 48, 48)
# Wall temperature scaling applied with factor 106. Max wall temp: 97.76588619312176
# Processing key 'velx' in file 'Twall-106.hdf5' with shape (2001, 48, 48)
# Processing key 'vely' in file 'Twall-106.hdf5' with shape (2001, 48, 48)
# Processing key 'x' in file 'Twall-106.hdf5' with shape (2001, 48, 48)
# Processing key 'y' in file 'Twall-106.hdf5' with shape (2001, 48, 48)
# File 'Twall-106.hdf5' processed and saved to '../../data/PoolBoiling-SubCooled-FC72-2D-0.1/redim_DS8/Twall-106.hdf5'.
# Processing key 'dfun' in file 'Twall-95.hdf5' with shape (2001, 48, 48)
# Processing key 'pressure' in file 'Twall-95.hdf5' with shape (2001, 48, 48)
# Processing key 'temperature' in file 'Twall-95.hdf5' with shape (2001, 48, 48)
# Wall temperature scaling applied with factor 95. Max wall temp: 86.61957317962504
# Processing key 'velx' in file 'Twall-95.hdf5' with shape (2001, 48, 48)
# Processing key 'vely' in file 'Twall-95.hdf5' with shape (2001, 48, 48)
# Processing key 'x' in file 'Twall-95.hdf5' with shape (2001, 48, 48)
# Processing key 'y' in file 'Twall-95.hdf5' with shape (2001, 48, 48)
# File 'Twall-95.hdf5' processed and saved to '../../data/PoolBoiling-SubCooled-FC72-2D-0.1/redim_DS8/Twall-95.hdf5'.
# Processing key 'dfun' in file 'Twall-102.hdf5' with shape (2001, 48, 48)
# Processing key 'pressure' in file 'Twall-102.hdf5' with shape (2001, 48, 48)
# Processing key 'temperature' in file 'Twall-102.hdf5' with shape (2001, 48, 48)
# Wall temperature scaling applied with factor 102. Max wall temp: 92.90349674088566
# Processing key 'velx' in file 'Twall-102.hdf5' with shape (2001, 48, 48)
# Processing key 'vely' in file 'Twall-102.hdf5' with shape (2001, 48, 48)
# Processing key 'x' in file 'Twall-102.hdf5' with shape (2001, 48, 48)
# Processing key 'y' in file 'Twall-102.hdf5' with shape (2001, 48, 48)
# File 'Twall-102.hdf5' processed and saved to '../../data/PoolBoiling-SubCooled-FC72-2D-0.1/redim_DS8/Twall-102.hdf5'.
# Processing key 'dfun' in file 'Twall-98.hdf5' with shape (2001, 48, 48)
# Processing key 'pressure' in file 'Twall-98.hdf5' with shape (2001, 48, 48)
# Processing key 'temperature' in file 'Twall-98.hdf5' with shape (2001, 48, 48)
# Wall temperature scaling applied with factor 98. Max wall temp: 89.61056329424132
# Processing key 'velx' in file 'Twall-98.hdf5' with shape (2001, 48, 48)
# Processing key 'vely' in file 'Twall-98.hdf5' with shape (2001, 48, 48)
# Processing key 'x' in file 'Twall-98.hdf5' with shape (2001, 48, 48)
# Processing key 'y' in file 'Twall-98.hdf5' with shape (2001, 48, 48)
# File 'Twall-98.hdf5' processed and saved to '../../data/PoolBoiling-SubCooled-FC72-2D-0.1/redim_DS8/Twall-98.hdf5'.
# Processing key 'dfun' in file 'Twall-92.hdf5' with shape (2001, 48, 48)
# Processing key 'pressure' in file 'Twall-92.hdf5' with shape (2001, 48, 48)
# Processing key 'temperature' in file 'Twall-92.hdf5' with shape (2001, 48, 48)
# Wall temperature scaling applied with factor 92. Max wall temp: 84.36216287335368
# Processing key 'velx' in file 'Twall-92.hdf5' with shape (2001, 48, 48)
# Processing key 'vely' in file 'Twall-92.hdf5' with shape (2001, 48, 48)
# Processing key 'x' in file 'Twall-92.hdf5' with shape (2001, 48, 48)
# Processing key 'y' in file 'Twall-92.hdf5' with shape (2001, 48, 48)
# File 'Twall-92.hdf5' processed and saved to '../../data/PoolBoiling-SubCooled-FC72-2D-0.1/redim_DS8/Twall-92.hdf5'.
# Processing key 'dfun' in file 'Twall-85.hdf5' with shape (2001, 48, 48)
# Processing key 'pressure' in file 'Twall-85.hdf5' with shape (2001, 48, 48)
# Processing key 'temperature' in file 'Twall-85.hdf5' with shape (2001, 48, 48)
# Wall temperature scaling applied with factor 85. Max wall temp: 77.80791423585201
# Processing key 'velx' in file 'Twall-85.hdf5' with shape (2001, 48, 48)
# Processing key 'vely' in file 'Twall-85.hdf5' with shape (2001, 48, 48)
# Processing key 'x' in file 'Twall-85.hdf5' with shape (2001, 48, 48)
# Processing key 'y' in file 'Twall-85.hdf5' with shape (2001, 48, 48)
# File 'Twall-85.hdf5' processed and saved to '../../data/PoolBoiling-SubCooled-FC72-2D-0.1/redim_DS8/Twall-85.hdf5'.
# Processing key 'dfun' in file 'Twall-103.hdf5' with shape (2001, 48, 48)
# Processing key 'pressure' in file 'Twall-103.hdf5' with shape (2001, 48, 48)
# Processing key 'temperature' in file 'Twall-103.hdf5' with shape (2001, 48, 48)
# Wall temperature scaling applied with factor 103. Max wall temp: 95.41430824128659
# Processing key 'velx' in file 'Twall-103.hdf5' with shape (2001, 48, 48)
# Processing key 'vely' in file 'Twall-103.hdf5' with shape (2001, 48, 48)
# Processing key 'x' in file 'Twall-103.hdf5' with shape (2001, 48, 48)
# Processing key 'y' in file 'Twall-103.hdf5' with shape (2001, 48, 48)
# File 'Twall-103.hdf5' processed and saved to '../../data/PoolBoiling-SubCooled-FC72-2D-0.1/redim_DS8/Twall-103.hdf5'.
# Scaling completed for all files.

# %%
# %%bash
# #tar -czf redim_DS8 /data/PoolBoiling-SubCooled-FC72-2D-0.1/redim_DS8
# Out:
# tar: data/PoolBoiling-SubCooled-FC72-2D-0.1/redim_DS8: Cannot stat: No such file or directory
# tar: Exiting with failure status due to previous errors
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', 'tar -czf redim_DS8 data/PoolBoiling-SubCooled-FC72-2D-0.1/redim_DS8\n')
#
# File /sw/arch/RHEL8/EB_production/2022/software/IPython/8.5.0-GCCcore-11.3.0/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2362, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2360 with self.builtin_trap:
#    2361     args = (magic_arg_s, cell)
# -> 2362     result = fn(*args, **kwargs)
#    2363 return result
#
# File /sw/arch/RHEL8/EB_production/2022/software/IPython/8.5.0-GCCcore-11.3.0/lib/python3.10/site-packages/IPython/core/magics/script.py:153, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     151 else:
#     152     line = script
# --> 153 return self.shebang(line, cell)
#
# File /sw/arch/RHEL8/EB_production/2022/software/IPython/8.5.0-GCCcore-11.3.0/lib/python3.10/site-packages/IPython/core/magics/script.py:305, in ScriptMagics.shebang(self, line, cell)
#     300 if args.raise_error and p.returncode != 0:
#     301     # If we get here and p.returncode is still None, we must have
#     302     # killed it but not yet seen its return code. We don't wait for it,
#     303     # in case it's stuck in uninterruptible sleep. -9 = SIGKILL
#     304     rc = p.returncode or -9
# --> 305     raise CalledProcessError(rc, cell)
#
# CalledProcessError: Command 'b'tar -czf redim_DS8 data/PoolBoiling-SubCooled-FC72-2D-0.1/redim_DS8\n'' returned non-zero exit status 2.

# %%
# %%bash
# cd ..
# cd ..
# cd data
# cd PoolBoiling-SubCooled-FC72-2D-0.1
# dir
# tar -czf redim_DS8.tar.gz redim_DS8
# Out:
# downsampled_8  redim_DS4  redim_DS8
