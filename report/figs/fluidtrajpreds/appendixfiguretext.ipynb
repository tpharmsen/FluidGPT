# %%
import sys
import os

# %%
# print the files in the current directory
filelist = os.listdir()
# sort the files by components 
filenames = sorted(filelist)
for filename in filenames:
    if filename.startswith("preds_"):
        # parse numbers from the filename
        numbers = filename.split("_")[2].split(".")[0]
        dataset = filename.split("_")[1].split(".")[0]
        print(rf"""
\begin{{figure}}[H]
    \centering
    \includegraphics[width=1\textwidth]{{figs/fluidtrajpreds/{filename}}}
    \caption{{Radial velocity components of the predicted and true trajectories for trajectory {numbers} of the dataset \texttt{{{dataset}}}.}}
\end{{figure}}
        """)
# Out:
# \begin{figure}[H]
#     \centering
#     \includegraphics[width=1\textwidth]{figs/fluidtrajpreds/preds_amira_102.png}
#     \caption{Radial velocity components of the predicted and true trajectories for trajectory 102 of the dataset \texttt{amira}.}
# \end{figure}
#
#
# \begin{figure}[H]
#     \centering
#     \includegraphics[width=1\textwidth]{figs/fluidtrajpreds/preds_amira_1253.png}
#     \caption{Radial velocity components of the predicted and true trajectories for trajectory 1253 of the dataset \texttt{amira}.}
# \end{figure}
#
#
# \begin{figure}[H]
#     \centering
#     \includegraphics[width=1\textwidth]{figs/fluidtrajpreds/preds_amira_2525.png}
#     \caption{Radial velocity components of the predicted and true trajectories for trajectory 2525 of the dataset \texttt{amira}.}
# \end{figure}
#
#
# \begin{figure}[H]
#     \centering
#     \includegraphics[width=1\textwidth]{figs/fluidtrajpreds/preds_amira_3110.png}
# ...

# %%
# print the files in the current directory
filelist = os.listdir()
# sort the files by components 
filenames = sorted(filelist)
for filename in filenames:
    if filename.startswith("vort_preds_"):
        # parse numbers from the filename
        numbers = filename.split("_")[3].split(".")[0]
        dataset = filename.split("_")[2].split(".")[0]
        print(rf"""
\begin{{figure}}[H]
    \centering
    \includegraphics[width=1\textwidth]{{figs/fluidtrajpreds/{filename}}}
    \caption{{Vorticity components of the predicted and true trajectories for trajectory {numbers} of the dataset \texttt{{{dataset}}}.}}
\end{{figure}}
        """)
